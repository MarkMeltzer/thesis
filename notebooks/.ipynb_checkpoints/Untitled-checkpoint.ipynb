# %%
import openpyxl as op
import urllib.request as req
import xml.etree.ElementTree as ET
import pandas as pd
import nltk
import matplotlib.pyplot as plt
import os

DATA_PATH = "../data"
XML_SCHEMAS = {
    'R2.0.9.S03.E01' : "{http://publications.europa.eu/resource/schema/ted/R2.0.9/publication}",
    'R2.0.9.S04.E01' : "{http://publications.europa.eu/resource/schema/ted/R2.0.9/publication}",
    'R2.0.9.S02.E01' : "{ted/R2.0.9.S02/publication}"
}

# %% [markdown]
# ### Downloading contracts

# %%
# download all frontex contracts referenced in sheets
contract_counter = 0
for sheet_file in os.listdir(DATA_PATH + "/sheets/"):
    wb = op.load_workbook(DATA_PATH + "/sheets/" + sheet_file)
    sheet = wb.active
    
    # download all contracts in XML format
    for row in sheet.rows:
        if "frontex" in row[3].value.lower() or "border" in row[3].value.lower():
            url = row[0].hyperlink.target.replace(":TEXT:", ":XML:")
            
            try:
                req.urlretrieve(url, DATA_PATH + "/XML/" + str(contract_counter) + ".xml")
                print(f"Saved {row[2].value} to {contract_counter}.xml")
            except Exception as E:
                print(E)

            contract_counter += 1
# Out:
# Saved Framework Contract for Purchase of Cooled Handheld Thermal Cameras for Border Surveillance to 0.xml
# Saved Framework Contract for Provision of Sanitary Supplies to 1.xml
# Saved Provision of Canteen Operator Services to 2.xml
# Saved Framework Contract for Leasing of Off-road Vehicles for Frontex Operational Activities to 3.xml
# Saved Framework Contract for Leasing of Off-road Vehicles for Frontex Operational Activities to 4.xml
# Saved Framework Contract for Leasing of Off-road Vehicles for Frontex Operational Activities to 5.xml
# Saved Framework Contract for Organisation of Events Outside of Poland to 6.xml
# Saved Provision of Office Supplies for Frontex to 7.xml
# Saved Framework Contract for the Supply of Document Inspection Devices for Frontex Joint Operations to 8.xml
# Saved Framework Contract for the Supply of Document Inspection Devices for Frontex Joint Operations to 9.xml
# Saved Delivery of Frontex Corporate Gifts to 10.xml
# Saved Delivery of Frontex Corporate Gifts to 11.xml
# Saved Delivery of Frontex Corporate Gifts to 12.xml
# Saved Delivery of Frontex Corporate Gifts to 13.xml
# Saved Single Framework Contract for the provision of ICT products and services for Eurosur to 14.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Function to 15.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Function to 16.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Function to 17.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Function to 18.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Function to 19.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Function to 20.xml
# Saved Provision of painting services for Frontex to 21.xml
# Saved Framework contract for the supply of handheld carbon dioxide detectors to 22.xml
# Saved Maritime analysis tools to 23.xml
# Saved Delivery and installation of furniture to 24.xml
# Saved Delivery and installation of furniture to 25.xml
# Saved Delivery and installation of furniture to 26.xml
# Saved Coastal Surveillance Aerostats — Deployment and Trial to 27.xml
# Saved Framework Contract for Aerial Surveillance Services Assets and Expert Support Lot 1 to 28.xml
# Saved Framework Contract for Aerial Surveillance Services Assets and Expert Support Lot 1 to 29.xml
# Saved Framework Contract for Aerial Surveillance Services Assets and Expert Support Lot 1 to 30.xml
# Saved Framework Contract for Aerial Surveillance Services Assets and Expert Support Lot 1 to 31.xml
# Saved Framework contract for the external quality assurance, accreditation and institutional review to 32.xml
# Saved Framework contract for the supply of handheld equipment for border surveillance and border checks to 33.xml
# Saved Framework contract for the supply of handheld equipment for border surveillance and border checks to 34.xml
# Saved Framework contract for the supply of handheld equipment for border surveillance and border checks to 35.xml
# Saved Framework contract for the supply of handheld equipment for border surveillance and border checks to 36.xml
# Saved Framework contract for the provision of handyman and messenger services for Frontex headquarters to 37.xml
# Saved Technical Support for Testing and Evaluation of a New Copernicus Service to 38.xml
# Saved Trial of Remotely Piloted Aircraft System (RPAS) for long endurance Maritime Aerial Surveillance to 39.xml
# Saved Trial of Remotely Piloted Aircraft System (RPAS) for long endurance Maritime Aerial Surveillance to 40.xml
# Saved Chartering aircraft and related services for return operations to 41.xml
# Saved Chartering aircraft and related services for return operations to 42.xml
# Saved Provision of painting services for Frontex to 43.xml
# Saved Provision of HID® FARGO® HDP5000 ID card printers, consumables and services to 44.xml
# Saved Framework Contract for Purchase of Cooled Handheld Thermal Cameras for Border Surveillance to 45.xml
# Saved Framework Contract for the Supply of Heart Beat Detectors (HBD) for Border Checks to 46.xml
# Saved Satellite Radio Frequency Emitter Detection for Maritime Situational Awareness to 47.xml
# Saved Provision of Maintenance Services of Audio-Video Equipment in Frontex Premises to 48.xml
# Saved Framework Contract for the Provision of Passenger Transfer Services by Sea from Mytilini (Locode GRMJT) to Dikili (Locode TRDIK) to 49.xml
# Saved Framework Contract for Provision of the Layout and Graphic Design Services to 50.xml
# Saved Framework Contract for Provision of the Layout and Graphic Design Services to 51.xml
# Saved Framework Contract for Provision of the Layout and Graphic Design Services to 52.xml
# Saved Provision of Interim Staff Services for Frontex to 53.xml
# Saved Provision of Interim Staff Services for Frontex to 54.xml
# Saved Provision of Interim Staff Services for Frontex to 55.xml
# Saved Provision of Interim Staff Services for Frontex to 56.xml
# Saved Framework Contract for Provision of Vehicles for Migration Management Support to 57.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 58.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 59.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 60.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 61.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 62.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 63.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 64.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 65.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 66.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 67.xml
# Saved Framework Contract for Provision of Interpretation Services to 68.xml
# Saved Framework Contract for the Provision of Professional Insurance Brokerage Services to 69.xml
# Saved Provision of Interim Staff Services for Frontex to 70.xml
# Saved Purchase of the Transportation Network Spatial Vector Data along the EU External Borders to 71.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated Services in Albania, Serbia, Bosnia and Herzegovina and Republic of North Macedonia to 72.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated Services in Albania, Serbia, Bosnia and Herzegovina and Republic of North Macedonia to 73.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated Services in Albania, Serbia, Bosnia and Herzegovina and Republic of North Macedonia to 74.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated Services in Albania, Serbia, Bosnia and Herzegovina and Republic of North Macedonia to 75.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated Services in Albania, Serbia, Bosnia and Herzegovina and Republic of North Macedonia to 76.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated Services in Albania, Serbia, Bosnia and Herzegovina and Republic of North Macedonia to 77.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated Services in Albania, Serbia, Bosnia and Herzegovina and Republic of North Macedonia to 78.xml
# Saved Framework Contract for the Provision of Mobile Office Containers and Associated Services in Albania, Serbia, Bosnia and Herzegovina and Republic of North Macedonia to 79.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Functions to 80.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Functions to 81.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Functions to 82.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Functions to 83.xml
# Saved Provision of Travel Desk Services for Frontex to 84.xml
# Saved Framework Contract for the Provision of Fuel Cards and Associated Services for Frontex Vehicles to 85.xml
# Saved Framework Contract for the Provision of Fuel Cards and Associated Services for Frontex Vehicles to 86.xml
# Saved Framework Contract for the Provision of Fuel Cards and Associated Services for Frontex Vehicles to 87.xml
# Saved Framework Contract for Organisation of Events in Poland to 88.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Functions to 89.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Functions to 90.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Functions to 91.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Functions to 92.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Functions to 93.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Functions to 94.xml
# Saved Chartering Aircraft and Related Services for Return Operations to 95.xml
# Saved Chartering Aircraft and Related Services for Return Operations to 96.xml
# Saved Returns by Scheduled Flights supported by Frontex to 97.xml
# Saved Framework Contract for Provision of Vehicles for Migration Management support to 98.xml
# Saved Purchase of the Transportation Network Spatial Vector Data along the EU External Borders to 99.xml
# Saved Provision of Nautical Charts Web Map Service Design, Transition and Operation to 100.xml
# Saved Framework Contract for the acquisition of SAS software licences to 101.xml
# Saved Maritime Surveillance Aerostat Trial to 102.xml
# Saved Delivery of Frontex Corporate Gifts to 103.xml
# Saved Provision of Cleaning Services for Frontex to 104.xml
# Saved Framework Contract for the Development of ICT Software Solution for the Management of Frontex Operational Resources – Opera System to 105.xml
# Saved Framework Contract for Procurement of Crisis Management Consultancy to 106.xml
# Saved Framework Contract for Courier Services for Frontex to 107.xml
# Saved Framework Contract for Courier Services for Frontex to 108.xml
# Saved Service Contract for the Provision of Emergency Response Services for Staff in Training Centres of Frontex in Poland to 109.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision of Software Development Services to 110.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision of Software Development Services to 111.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision of Software Development Services to 112.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision of Software Development Services to 113.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision of Software Development Services to 114.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision of Software Development Services to 115.xml
# Saved Purchase of Training and Environmental Data Update for SARMAP Software to 116.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Functions — Lot 2 to 117.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Functions — Lot 2 to 118.xml
# Saved Framework Contract for the Provision of Language Courses for Frontex Staff to 119.xml
# Saved Framework Contract for the Provision of Language Courses for Frontex Staff to 120.xml
# Saved Provision of Door-to-door Transportation Services for Frontex Vehicles to 121.xml
# Saved Provision of Door-to-door Transportation Services for Frontex Vehicles to 122.xml
# Saved Provision of Door-to-door Transportation Services for Frontex Vehicles to 123.xml
# Saved Swecurity Services in EURTF Catania to 124.xml
# Saved Remotely Piloted Aircraft Systems (RPAS) for Medium Altitude Long Endurance Maritime Aerial Surveillance to 125.xml
# Saved Remotely Piloted Aircraft Systems (RPAS) for Medium Altitude Long Endurance Maritime Aerial Surveillance to 126.xml
# Saved Purchase of Multifunctional Scanning Peripherals to 127.xml
# Saved Purchase of Multifunctional Scanning Peripherals to 128.xml
# Saved Multiple Framework Contract in Cascade for the Provision of Legal/Consultancy Services to 129.xml
# Saved Multiple Framework Contract in Cascade for the Provision of Legal/Consultancy Services to 130.xml
# Saved Multiple Framework Contract in Cascade for the Provision of Legal/Consultancy Services to 131.xml
# Saved Multiple Framework Contract in Cascade for the Provision of Legal/Consultancy Services to 132.xml
# Saved Framework Contract for the Provision of Fresh Fruit and Vegetables to Frontex Premises to 133.xml
# Saved Security Services in EURTF Catania to 134.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision of Consultancy Services to 135.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision of Consultancy Services to 136.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision of Consultancy Services to 137.xml
# Saved Framework Contract for Purchase of Training Outfits to 138.xml
# Saved Framework Contract for Purchase of Training Outfits to 139.xml
# Saved Short Notice Chartering of Aircraft for Frontex Operational Activities to 140.xml
# Saved Short Notice Chartering of Aircraft for Frontex Operational Activities to 141.xml
# Saved Short Notice Chartering of Aircraft for Frontex Operational Activities to 142.xml
# Saved Short Notice Chartering of Aircraft for Frontex Operational Activities to 143.xml
# Saved Framework Contract for Provision of Mobile Surveillance Systems for Frontex Operational Activities — Lot 2 to 144.xml
# Saved Provision of Medical Services – Pre-recruitment Examination to 145.xml
# Saved Framework Contract for Provision of Mobile Surveillance Systems for Frontex Operational Activities to 146.xml
# Saved Framework Contract for Provision of Mobile Surveillance Systems for Frontex Operational Activities to 147.xml
# Saved Remote Assessment of English Language Skills to 148.xml
# Saved Framework Contract for Provision of Interpretation and Cultural Expertise Services to 149.xml
# Saved Framework Contract for Provision of Interpretation and Cultural Expertise Services to 150.xml
# Saved Framework Contract for Provision of Interpretation and Cultural Expertise Services to 151.xml
# Saved Framework Contract for Provision of Interpretation and Cultural Expertise Services to 152.xml
# Saved Framework Contract for Provision of Interpretation and Cultural Expertise Services to 153.xml
# Saved Testing and Evaluation of a New Copernicus Service: Combined Time/Area Imagery to 154.xml
# Saved Framework Contract for the Provision of Mobile and Toilet Office Containers and Associated Services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 155.xml
# Saved Framework Contract for the Provision of Mobile and Toilet Office Containers and Associated Services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 156.xml
# Saved Framework Contract for the Provision of Mobile and Toilet Office Containers and Associated Services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 157.xml
# Saved Framework Contract for the Provision of Mobile and Toilet Office Containers and Associated Services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 158.xml
# Saved Framework Contract for the Provision of Mobile and Toilet Office Containers and Associated Services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 159.xml
# Saved Framework Contract for the Provision of Mobile and Toilet Office Containers and Associated Services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 160.xml
# Saved Framework Contract for the Provision of Mobile and Toilet Office Containers and Associated Services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 161.xml
# Saved Framework Contract for the Provision of Mobile and Toilet Office Containers and Associated Services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 162.xml
# Saved Framework Contract for the Provision of Mobile and Toilet Office Containers and Associated Services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 163.xml
# Saved Framework Contract for the Provision of Mobile and Toilet Office Containers and Associated Services in Cyprus, Kosovo, Moldova, Montenegro and Ukraine to 164.xml
# Saved Service Contract for the Provision of Social Media Analysis Services Concerning Irregular Migration Trends and Forecasts (as part of Pre-warning Mechanism) to 165.xml
# Saved Framework Service Contract for Administrative, Proactive and Reactive Services to Data Centre Equipment and Systems to 166.xml
# Saved Aerial Surveillance Services for Border and Coast Guard Functions to 167.xml
# Saved Provision of Research and Innovation Assistance and Advisory Services to 168.xml
# Saved Provision of Research and Innovation Assistance and Advisory Services to 169.xml
# Saved Provision of Research and Innovation Assistance and Advisory Services to 170.xml
# Saved Purchase of Multifunctional Scanning Peripherals to 171.xml
# Saved Purchase of Multifunctional Scanning Peripherals to 172.xml
# Saved Leasing or Long-term Lease of Vehicles and Associated Services for Frontex Operational Activities to 173.xml
# Saved Leasing or Long-term Lease of Vehicles and Associated Services for Frontex Operational Activities to 174.xml
# Saved Entry Exit System Land Border Pilot to 175.xml
# Saved Entry Exit System Land Border Pilot to 176.xml
# Saved Framework Contract for the Provision of Fuel Cards Services and Associated Services for Frontex Vehicles to 177.xml
# Saved Framework Contract for the Provision of Fuel Cards Services and Associated Services for Frontex Vehicles to 178.xml
# Saved Single Framework Contract for Satellite Imagery Provisioning to 179.xml
# Saved Cisco Advanced Services to 180.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision Services for Development, Consultancy and Support of Information Systems under Time and Means Conditions to 181.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision Services for Development, Consultancy and Support of Information Systems under Time and Means Conditions to 182.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision Services for Development, Consultancy and Support of Information Systems under Time and Means Conditions to 183.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision Services for Development, Consultancy and Support of Information Systems under Time and Means Conditions to 184.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision Services for Development, Consultancy and Support of Information Systems under Time and Means Conditions to 185.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision Services for Development, Consultancy and Support of Information Systems under Time and Means Conditions to 186.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision Services for Development, Consultancy and Support of Information Systems under Time and Means Conditions to 187.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision Services for Development, Consultancy and Support of Information Systems under Time and Means Conditions to 188.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision Services for Development, Consultancy and Support of Information Systems under Time and Means Conditions to 189.xml
# Saved Multiple Framework Contract with Reopening of Competition for the Provision Services for Development, Consultancy and Support of Information Systems under Time and Means Conditions to 190.xml
# Saved Maritime Analysis Tools to 191.xml
# Saved Research Study on Technology Foresight on Biometrics for the Future of Travel to 192.xml
# Saved Maritime Surveillance Aerostat 2 Technology Pilot to 193.xml

# %% [markdown]
# ### Extracting schort descriptions as corpus

# %%
def get_short_descr(xml_tree):
    schema = XML_SCHEMAS[xml_tree.getroot().attrib.get('VERSION')]

    form_section = xml_tree.getroot().find(schema + "FORM_SECTION")
    if not form_section:
        return None
    
    description_parts = list(form_section[2].find(schema + "OBJECT_CONTRACT")
                                            .find(schema + "SHORT_DESCR"))
    return "\n".join(elem.text for elem in description_parts)

# %%
# TODO: handle multiple files concerning the same contract (probably just require unique descriptions <-- not quite, some are unique but almost the same)

# create corpus from all short descriptions
descriptions = []
for contract in os.listdir(DATA_PATH + "/XML/"):
    xml_tree = ET.parse(DATA_PATH + "/XML/" + contract)
    
    short_description = get_short_descr(xml_tree)
    if not short_description:
        print(f"Error parsing contract: {contract}")
    else:
        if short_description not in descriptions:
            descriptions.append(short_description)

corpus = " ".join(descriptions)
words = nltk.word_tokenize(corpus)

stop_words = nltk.corpus.stopwords.words("english")
clean_words = []
for word in words:
    word = word.lower()
    if word.isalpha() and word not in stop_words:
        clean_words.append(word)
# Out:
# C:\Users\Mathias\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The behavior of this method will change in future versions.  Use specific 'len(elem)' or 'elem is not None' test instead.
#   """

# %%
# print all descriptions containing the word surveillance, see that some are
# technically unique but basically the same, these probably come from multiple lots
# of the same contract
for d in descriptions:
    if "urveillance" in d:
        print(d)
        print("="*80)
# Out:
# Framework contract for purchasing of cooled handheld thermal cameras for border surveillance.
# ================================================================================
# The global objective of this tender is to lease one surveillance aerostat to carry out a pilot project, supported by a host Member State: Greece, aiming to assess the capacity and cost efficiency of aerostat performing maritime surveillance in an operational environment. The scope of the tender is then to establish a service contract to deploy, operate and assess for a period of minimum of three weeks one surveillance aerostat, including in the contract the provision of the equipment and experts to conduct the trial.
# ================================================================================
# The global objective of this tender is to enable Frontex and EFCA to have at their disposal aerial surveillance equipment, with a high level of deployability and availability that should permit these agencies to cover their requirements for operational surveillance capability. The scope of this tender is to establish a framework contract (FWC) with re-opening of competition, in order to acquire manned aerial surveillance services, which should include assets and experts. Frontex and EFCA seek medium term cooperation with a maximum of 10 contractors providing aerial surveillance in each of the lots of the FWC, offering the best ‘value for money’ and able to sustain readiness for cost-efficient surveillance services along the duration of the FWC.
# ================================================================================
# Frontex is looking to acquire aerial surveillance services by the means of Medium Altitude Long Endurance Remotely Piloted Aircraft System (MALE RPAS) for maritime purposes. The service will be delivered in Greece and/or in Italy and/or in Malta within a framework contract signed between Frontex and the contractor. The aerial surveillance service shall include reliable close to real time live data streaming and data sharing capacity in the requested formats. Frontex is looking for a complete service providing all the necessary technical and human resources, including obtaining the applicable permissions and certificates.
# ================================================================================
# The scope of this tender is to establish a single framework contract divided into three lots with commercial providers for delivery of mobile surveillance systems. A single asset delivered shall include a four-wheel-drive vehicle (a pick-up for lot 1 and a van for lots 2 and 3) with a system of surveillance sensors – thermal camera, day camera and surveillance radar (surveillance radar is required only for lot 3) installed on board, as well as a communication system, including all the necessary devices and software to control the surveillance sensors and the entire system.
# ================================================================================
# The scope of this tender is to establish a single framework contract divided into three lots with commercial providers for delivery of mobile surveillance systems. A single asset delivered shall include a four-wheel-drive vehicle (a pick-up for lot 1 and a van for lots 2 and 3) with a system of surveillance sensors — thermal camera, day camera and surveillance radar (surveillance radar is required only for lot 3) installed on board, as well as a communication system, including all the necessary devices and software to control the surveillance sensors and the entire system.
# ================================================================================
# The global objective of this tender is to enable Frontex and EFCA to have at their disposal aerial surveillance equipment, with a high level of deployability and availability that should permit these agencies to cover their requirements for operational surveillance capability.
# The scope of this tender is to establish a Framework contract (FWC) with re-opening of competition, in order to acquire Aerial surveillance services, which should include assets and experts. Frontex and EFCA seek medium term cooperation with a minimum of 3 and a maximum of 10 contractors providing Aerial surveillance in each of the Lots of the FWC, offering the best “value for money”, and able to sustain readiness for cost-efficient surveillance services, termed competitive Specific contracts, along the duration of the FWC.
# ================================================================================
# The global objective of this tender is to lease two surveillance aerostats to carry out a second pilot project, supported by a host Member State: Greece, aiming to assess the capacity and cost efficiency of aerostats performing maritime surveillance in an operational environment. The scope of the tender is then to establish a service contract to deploy, operate and assess for a period of minimum of four months and maximum of six months two surveillance aerostats, including in the contract the provision of the equipment and experts to conduct the trial.
# ================================================================================
# The procurement defined in this document consists of the delivery by 2 different providers of 2 sets of surveillance aerostats, data transmission, payload control and the necessary expertise to deploy and manage them. These 2 systems will be used for the execution of a pilot project to test, compare, and evaluate different surveillance aerostat. The deployment, test, and evaluation will be carried out in 2 fixed points of the coast of 1EU Member State, over a specified time-line.
# ================================================================================
# Frontex seeks to sign contracts to conduct the trial of long endurance maritime surveillance with 2 types of RPAS: MALE and Small MALE. These platforms will fly up to 600 and 300 hours respectively, over a period of 120 calendar days in 2018. The trials will take place in areas of the Mediterranean Sea designated by Frontex in cooperation with one or more host Member States within the time frame of Q2-Q4 2018.
# ================================================================================
# Purchase of cooled handheld thermal cameras for border surveillance under framework contract.
# ================================================================================
# The global objective of this tender is to enable Frontex and EFCA to have at their disposal aerial surveillance equipment, with a high level of deployability and availability that should permit these agencies to cover their requirements for operational surveillance capability. The scope of this tender is to establish a Framework Contract (FWC) with re-opening of competition, in order to acquire manned aerial surveillance services, which should include assets and experts. Frontex and EFCA seek medium term cooperation with a maximum of 10 Contractors providing aerial surveillance in each of the lots of the FWC, offering the best ‘value for money’, and able to sustain readiness for cost-efficient surveillance services along the duration of the FWC.
# ================================================================================
# The global objective of this tender is to enable Frontex and EFCA to have at their disposal aerial surveillance equipment, with a high level of deployability and availability that should permit these agencies to cover their requirements for operational surveillance capability. The scope of this tender is to establish a Framework Contract (FWC) with re-opening of competition, in order to acquire manned aerial surveillance services, which should include assets and experts. Frontex and EFCA seek medium term cooperation with a maximum of 10 contractors providing aerial surveillance in each of the Lots of the FWC, offering the best “value for money”, and able to sustain readiness for cost-efficient surveillance services along the duration of the FWC.
# ================================================================================

# %%
len(corpus)
# Out:
# 29844

# %% [markdown]
# ### Plotting word frequency

# %%
ignore_words = ["frontex", "lot", "lots", "contract", "tender", "ii", "services", "framework"]
fdist = nltk.probability.FreqDist([word for word in clean_words if word not in ignore_words])
fig = plt.figure(figsize = (15,6))
plt.rcParams.update({'font.size': 15})
fdist.plot(40)

# %%
fdist.freq('systems')*fdist.N()
# Out:
# 14.0

# %%
fdist.freq('analysis')*fdist.N()
# Out:
# 7.0

# %% [markdown]
# # Getting contractor award counts from EXCL sheets

# %%
df1 = pd.read_excel(DATA_PATH + "/sheets/2019_AG.xlsx", engine='openpyxl')
df2 = pd.read_excel(DATA_PATH + "/sheets/2020_AG.xlsx", engine='openpyxl')
df3 = pd.read_excel(DATA_PATH + "/sheets/2021_AG.xlsx", engine='openpyxl')
df4 = pd.read_excel(DATA_PATH + "/sheets/2018_AG.xlsx", engine='openpyxl')
df = pd.concat([df1, df2, df3, df4], ignore_index=True)
# Out:
# C:\Users\Mathias\AppData\Local\Programs\Python\Python36\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
frontex = df[df['Contracting Authority name'].str.contains('(?i)Border|Frontex')] # (?i) = ignore case

print(f"Number of records: {len(frontex)}")
print(f"Number of unique contractors: {len(frontex['Contractor awarded'].unique())}")
print(f"Total value of contracts: {frontex['Value of the Contract'].sum()}")
# Out:
# Number of records: 194
# Number of unique contractors: 124
# Total value of contracts: 1066255312.125

# %%
# Look for a keyword in all titles
keyword = 'Analysis'
res = frontex[frontex['Title of the notice'].str.contains(keyword).fillna(False)]['Title of the notice']
for key in res.keys():
    print(res[key])
# Out:
# Service Contract for the Provision of Social Media Analysis Services Concerning Irregular Migration Trends and Forecasts (as part of Pre-warning Mechanism)
# Maritime Analysis Tools

# %%
# sometimes multiple companies are listed as a single contractor
combined_contractors = frontex['Contractor awarded'].unique()
print(f"n of combined contractors from sheets: {len(combined_contractors)}")
contractors = list(set([c for c_list in frontex['Contractor awarded'].unique() for c in c_list.split("---")]))
print(f"n of unique (split) contractors: {len(contractors)}")
# Out:
# n of combined contractors from sheets: 124
# n of unique (split) contractors: 147

# %%
# manual mapping from different spellings of a company name to a single company tag
contractor_dict = {
    'EDISOFT-Empresa de Servicos e Desenvolvimento de Software, S.A.': 'edisoft',
    'Korporacja Wschód Sp. z o.o.' : 'Korporacja Wschód',
    'Pol-Mare Sp.Zo.o' : 'Pol-Mare',
    'Asseco Poland S.A.' : 'Asseco Poland',
    'ESRI Polska' : 'ESRI Polska',
    'TNT Express Worldwide (Poland) sp. z o.o.' : 'TNT Express',
    'Steinbeis 2I GMBH' : 'Steinbeis',
    'Cambridge School of English Sp. z o.o.' : 'Cambridge School of English',
    'FINCONS S.P.A. (Partner)' : 'FINCONS',
    'Bene Warszawa Sp ZOO' : 'Bene Warszawa',
    'Control system FMN Sp z oo': 'Control system FMN',
    'European Dynamics SA' : 'European Dynamics',
    'PWC — Pricewaterhousecoopers EU Services EESV' : 'PWC',
    'Ekotoi Ltd' : 'Ekotoi',
    'Fleischhacker GmbH and Co. KG' : 'Fleischhacker',
    'Carmenta AB' : 'Carmenta',
    'Mleasing Sp. z o.o.' : 'Mleasing',
    'Pecka Studio s.r.o.' : 'Pecka Studio',
    'Jarosław Sztobryn Prooffice' : 'Jarosław Sztobryn Prooffice',
    'Squire Patton Boggs Święcicki i Krześniak SP.K.' : 'Squire Patton Boggs',
    'Consortium ATOS POLSKA S.A. (leader)' : 'ATOS POLSKA',
    'Centro Informazione e Educazione Allo Sviluppo Onlus' : 'Centro Informazione e Educazione Allo Sviluppo Onlus',
    'CPD Systems SP. Z O.O.' : 'CPD Systems',
    'Optix SA' : 'Optix',
    'CNIM AIR SPACE SAS' : 'CNIM AIR SPACE',
    'Brill AV Media Sp z oo' : 'Brill AV Media',
    'Bird and Bird Szepietowski i Wspólnicy SP.K.' : 'Bird and Bird',
    'Intrasoft International S.A.' : 'Intrasoft International',
    'ISDEFE – Ingenieria Sistemas Para la Defensa de Espana' : 'ISDEFE',
    'Grafton Recruitment Sp z oo' : 'Grafton Recruitment',
    'Optexim AD' : 'Optexim',
    'Airbus DS Airborne Solutions GmbH' : 'Airbus',
    'e-GEOS SPA' : 'e-GEOS',
    'Pomilio Blumm SRL' : 'Pomilio Blumm',
    'Altia Consultores S.A.' : 'Altia Consultores',
    'Ricardo Nederland BV' : 'Ricardo',
    'Car Master 2 sp. z o.o. sp.k.' : 'Car Master 2',
    'Hawkeye 360, Inc.' : 'Hawkeye 360',
    'Solten France Societe a Responsabilite Limitee' : 'Solten',
    'Professional Aviation Solutions GmbH' : 'Professional Aviation Solutions',
    'Art’ Impression Catering Sp. z o.o.' : 'Art’ Impression Catering',
    'New Wave GmbH' : 'New Wave',
    'Kancelaria Radców Prawnych Cwik i Partnerzy SP.P.' : 'Kancelaria Radców Prawnych Cwik i Partnerzy',
    'Ricardo-AEA Ltd': 'Ricardo',
    'Ashurst LLP' : 'Ashurst',
    'Dat-Con d.o.o.' : 'Dat-Con',
    'Consortium of Oktagon Polska Paweł Toffel, AndRee GROUP Andrzej Toffel, ADART S.C. led by Oktagon Polska Paweł Toffel' : 'Oktagon Polska Paweł Toffel',
    'Maxi Cargo Sp.Zo.o' : 'Maxi Cargo',
    'Ingenieria De Sistemas Para La Defensa De Espana S.A., S.M.E., M.P.' : 'Ingenieria De Sistemas Para La Defensa De Espana',
    'Engineering Ingegneria Informatica S.P.A.' : 'Engineering Ingegneria Informatica',
    'European Dynamics Luxembourg SA' : 'European Dynamics',
    'Trasys International G.E.I.E.' : 'Trasys International',
    'DEA Aviation' : 'DEA Aviation',
    'Andree Group Andrzej Toffel' : 'Andree Group Andrzej Toffel',
    'IGEP SA/NV' : 'IGEP',
    'Ekotoi Ltd.' : 'Ekotoi',
    'ClanTect Ltd' : 'ClanTect',
    'eTravel SA' : 'eTravel',
    'JIT Team SP. Z O.O.' : 'JIT Team',
    'Softwin SRL' : 'Softwin',
    'Air Partner International GmbH' : 'Air Partner International',
    'Air Charter Service Limited' : 'Air Charter Service',
    'The Bridge – English Language Centre s.r.o.' : 'The Bridge',
    'GAF AG' : 'GAF',
    'Dom Volvo Car Sp. z o.o.' : 'Dom Volvo Car',
    'DEA Aviation Ltd' : 'DEA Aviation',
    'Sicurtransport' : 'Sicurtransport',
    'Hellenic Telecommunications Organization S.A. – OTE S.A. (Leader)' : 'Hellenic Telecommunications Organization',
    'Fly4Less Kft' : 'Fly4Less',
    'Air Charter Service Ltd' : 'Air Charter Service',
    'PricewaterhouseCoopers EU Services EESV' : 'PWC',
    'IN-innovative navigation GmbH' : 'IN-innovative navigation',
    'Air Charter Service GmbH' : 'Air Charter Service',
    'Israel Aerospace Industries Limited, Malat Division' : 'Israel Aerospace Industries',
    'PWC – Pricewaterhousecoopers EU Services EESV' : 'PWC',
    'City & Guilds of London Institute' : 'City & Guilds of London Institute',
    'Airborne Technologies GmbH' : 'Airborne Technologies',
    'SAS Institute Polska Sp. z o.o.' : 'SAS Institute',
    'Decuatro Marketing Promocional S.L.' : 'Decuatro Marketing Promocional',
    'Defacto Sp z oo' : 'Defacto',
    'Synergasia Cooperativa Sociale Onlus' : 'Synergasia Cooperativa Sociale Onlus',
    'EU Legis Avocats' : 'EU Legis Avocats',
    'Bird & Bird Szepietowski i Wspólnicy SP.K.' : 'Bird and Bird',
    'Pinpoint Corporate Services Ltd' : 'Pinpoint Corporate Services',
    'Deloitte — Deloitte Consulting and Advisory CVBA' : 'Deloitte',
    'in-innovative navigation GmbH' : 'IN-innovative navigation',
    'Miller Canfield W.Babicki, A.Chelchowski i Wspólnicy SP.K.' : 'Miller Canfield W.Babicki, A.Chelchowski i Wspólnicy',
    'DC System Company Sp z oo' : 'DC System Company',
    'ARHS Developments S.A.' : 'ARHS Developments',
    'EASP Air BV' : 'EASP Air',
    'Ekotoi Service Ltd' : 'Ekotoi',
    'Diamond-Executive Aviation Ltd' : 'Diamond-Executive Aviation',
    'Kaliszuk sp j staff partners' : 'Kaliszuk sp j staff partners',
    'Espes Office Sp ZOO' : 'Espes Office',
    'Outworking SA' : 'Outworking',
    'IDOM Consulting, Engineering and Architecture' : 'IDOM',
    'ZRB Walko Waldemar Koński' : 'ZRB Walko',
    'Instytut Systemów Bezpieczeństwa Sp. z o.o.' : 'Instytut Systemów Bezpieczeństwa',
    'Asseco Poland SA' : 'Asseco',
    'Daldewolf' : 'Daldewolf',
    'GMV Aerospace and Defence SAU' : 'GMV',
    'Telespazio France SAS' : 'Telespazio',
    'CAE Aviation' : 'CAE Aviation',
    'Elbit Systems Ltd, Advanced Technology Center' : 'Elbit Systems',
    'GMV Aerospace and Defence S.A.U.' : 'GMV',
    'Hogan Lovells (Warszawa) LLP (Spółka partnerska) Oddział w Polsce' : 'Hogan Lovells',
    'UNI Systems Information Technology Systems Commercial S.M.S.A. (Partner)' : 'UNI Systems',
    'OPTIX JSC' : 'Optix',
    'Seprotec Traduccion e Intepretacion Sociedad Limitada' : 'Seprotec',
    'Not awarded' : 'Not awarded',
    'UNI Systems Luxembourg S.a.r.l. (Partner)' : 'UNI Systems',
    'Leonardo SPA' : 'Leonardo',
    'Indra Sistemas SA' : 'Indra Sistemas',
    'Bechtle Brussels NV' : 'Bechtle',
    'Opticoelectron Group' : 'Opticoelectron Group',
    'PWC IT Services SP. Z O.O. (Partner)' : 'PWC',
    'Car Master 2 Sp. z o.o. Sp.k' : 'Car Master 2',
    'Avalon Tecnologías de la Información S.L.' : 'Avalon',
    'Lazaris A. Gomos D. OE' : 'Lazaris A. Gomos D.',
    'Nord Partner sp. z o.o.' : 'Nord Partner',
    'Jas Technologie Sp z oo' : 'Jas Technologie',
    'Soitron Group SE' : 'Soitron Group',
    'Robert Wagner — Wagner Werbemittel und Textilproduktion' : 'Robert Wagner',
    'Glassart S.A.' : 'Glassart',
    'Windward Ltd' : 'Windward',
    'TEKNE Srl' : 'TEKNE',
    'CAE Aviation Sarl' : 'CAE Aviation',
    'Sopra Steria Benelux SA/NV' : 'Sopra Steria',
    'ITBM LLC' : 'ITBM',
    'BHO Baumann, Heinrich, Ortner Rechtsanwalte und Patentanwalt Partnerschaft MBB' : 'BHO',
    'International SOS (Belgium) SPRL' : 'International SOS',
    'GI Group Sp z oo' : 'GI Group',
    'EPRD consortium – Office for Economic Policy and Regional Development' : 'EPRD consortium',
    'VISION BOX -SOLUCOES DE VISAO PORCOMPUTADOR SA' : 'VISION BOX',
    'Regula Baltija Ltd' : 'Regula Baltija',
    'EVERIS AEROESPACIAL Y DEFENSA SL' : 'EVERIS',
    'GTC AMG sp. z o.o.' : 'GTC AMG',
    'AS Aircontact' : 'Aircontact',
    'Atende SA' : 'Atende',
    'Computer Resources International S.A. (Partner)' : 'Computer Resources International',
    'Arlen S.A.' : 'Arlen',
    'PWC EU Services EESV (Leader)' : 'PWC',
    'Opticoelectron Group JSCo' : 'Opticoelectron Group',
    'Fabrity SP. Z O.O.' : 'Fabrity',
    'Accenture SP. Z O.O.' : 'Accenture',
    "ITC — Interpreti e Traduttori in Cooperativa Societa' Cooperativa" : 'ITC',
    'DSV Air and Sea Sp.Zo.o' : 'DSV'
}
unmapped_contractors = len([c for c in contractors if c not in contractor_dict])

# n of contracts awarded per contractor
contractor_counts = {}
for index, row in frontex.iterrows():
    split_contractors = row['Contractor awarded'].split("---")
    
    for contractor in split_contractors:
        tag = contractor_dict[contractor]
        
        if tag in contractor_counts:
            contractor_counts[tag] += 1
        else:
            contractor_counts[tag] = 1

# %%
sorted_counts = sorted(zip(contractor_counts.values(), contractor_counts.keys()), reverse=False)[:]

fig = plt.figure(figsize = (6,35))
plt.barh([x for _,x in sorted_counts], [x for x,_ in sorted_counts])
# Out:
# <BarContainer object of 128 artists>
